# %% [markdown]
# # 2. Pandas Exercises
#
# Fill in the blanks with the instruction code for a fulfilled program.

# %% [markdown]
# #### Import pandas

# %%
import pandas as pd

# %% [markdown]
# #### Create a series
# - create a list of series-> s1= [3, 2, 0, 1] and s2 =[0, 3, 7, 2] then convert them to the Data frame set column in "apple" and "orange"
# - ![image.png](attachment:image.png)

# %%
#create a series of data first, then convert to data dictionary type
# Create Series lists
s1 = [3, 2, 0, 1]
s2 = [0, 3, 7, 2]

# Convert to DataFrame
df = pd.DataFrame({
    "apple": s1,
    "orange": s2
})

df
# Out:
#    apple  orange
# 0      3       0
# 1      2       3
# 2      0       7
# 3      1       2

# %% [markdown]
# #### Create a data dictionary of
# - data = {
#     'weight': [45,50,60,55],
#     'height': [155,156,170,160]
# }

# %%
#create a data as a dictionary type
data = {
    'weight': [45, 50, 60, 55],
    'height': [155, 156, 170, 160]
}
data
# Out:
# {'weight': [45, 50, 60, 55], 'height': [155, 156, 170, 160]}

# %% [markdown]
# #### Create Data Frame in "df" from data dictionary
# ![image.png](attachment:image.png)

# %%
# df => pandas DataFrame object
df = pd.DataFrame(data)
df
# Out:
#    weight  height
# 0      45     155
# 1      50     156
# 2      60     170
# 3      55     160

# %% [markdown]
# #### Set index of Data Frame (df) in ['student#1', 'student#2', 'student#3', 'student#4']
# - ![image.png](attachment:image.png)

# %%
df =pd.DataFrame(data,index = ['student#1', 'student#2', 'student#3', 'student#4'])

df
# Out:
#            weight  height
# student#1      45     155
# student#2      50     156
# student#3      60     170
# student#4      55     160

# %% [markdown]
# ### using function head() to show as first two rows

# %%
df.head(2)
# Out:
#            weight  height
# student#1      45     155
# student#2      50     156

# %% [markdown]
# ### using function tail() to show as last two rows

# %%
df.tail(2)
# Out:
#            weight  height
# student#3      60     170
# student#4      55     160

# %% [markdown]
# ### using attribute shape to check shape of data frame

# %%
df.shape
# Out:
# (4, 2)

# %% [markdown]
# ### using attribute info to check information of data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, student#1 to student#4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  4 non-null      int64
#  1   height  4 non-null      int64
# dtypes: int64(2)
# memory usage: 96.0+ bytes

# %% [markdown]
# ### using function loc to find the information of
# weight     55
# height    160
# - ![image.png](attachment:image.png)

# %%
df.loc['student#4']
# Out:
# weight     55
# height    160
# Name: student#4, dtype: int64

# %% [markdown]
# ## +++++++++++++++++++++++++++++++++++++++
# ## Using Read csv file
# - read file name "nba-2.csv"
# - create data frame name as "dfNBA"
# - show top 5 records

# %%
import pandas as pd

dfNBA = pd.read_csv(r"C:\Users\LAB\Downloads\nba-2.csv")

dfNBA.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
##location of file on Doogle Drive 
#from google.colab import drive
#drive.mount('/content/drive')
#data_dir = "drive/My Drive/SE-Lectures-Materials/Intro to Data Analysis/nba-2.csv"

# %% [markdown]
# ### Using function count() to check total of members

# %%
# Count non-null values in each column
dfNBA.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %% [markdown]
# ### Using function set_index()
# - Set column "Name" to be index data
# - Show first 10 rows records

# %%
# Set column "Name" as index
dfNBA = dfNBA.set_index("Name")

# Show first 10 rows
dfNBA.head(10)
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0   238.0
# Terry Rozier   Boston Celtics    12.0       PG  22.0    6-2   190.0
# Marcus Smart   Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#                          College      Salary
# Name
# Avery Bradley              Texas   7730337.0
# Jae Crowder            Marquette   6796117.0
# John Holland   Boston University         NaN
# R.J. Hunter        Georgia State   1148640.0
# Jonas Jerebko                NaN   5000000.0
# Amir Johnson                 NaN  12000000.0
# Jordan Mickey                LSU   1170960.0
# Kelly Olynyk             Gonzaga   2165160.0
# Terry Rozier          Louisville   1824360.0
# Marcus Smart      Oklahoma State   3431040.0

# %% [markdown]
# ### Using attribute loc[ ] to find the information of  "Amir Johnson" and "Terry Rozier"
# - which shown in 3 columns ['Age', 'College', 'Salary']
# - ![image.png](attachment:image.png)

# %%
# Find information for Amir Johnson and Terry Rozier
dfNBA.loc[
    ["Amir Johnson", "Terry Rozier"],
    ["Age", "College", "Salary"]
]
# Out:
#                Age     College      Salary
# Name
# Amir Johnson  29.0         NaN  12000000.0
# Terry Rozier  22.0  Louisville   1824360.0

# %% [markdown]
# ### Using function loc() to
# - Find the all information in 3 columns ['Age', 'College', 'Salary']
# - Show first 5 rows ![image.png](attachment:image.png)

# %%
#Selecting all of the rows and some columns
# Select columns Age, College, Salary
# Show first 5 rows
dfNBA.loc[:, ['Age', 'College', 'Salary']].head(5)
# Out:
#                 Age            College     Salary
# Name
# Avery Bradley  25.0              Texas  7730337.0
# Jae Crowder    25.0          Marquette  6796117.0
# John Holland   27.0  Boston University        NaN
# R.J. Hunter    22.0      Georgia State  1148640.0
# Jonas Jerebko  29.0                NaN  5000000.0

# %% [markdown]
# # Good Job!
