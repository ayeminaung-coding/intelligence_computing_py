# %% [markdown]
# # Lab04: Data Cleaning
# #Fill in the blanks with the instruction code for a fulfilled program.

# %% [markdown]
# ## Import Python Package
# * NumPy and Pandas
# * import matplotlib.pyplot as plt and %matplotlib inline
# * import seaborn as sns

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# ### Input Dataset
# * read csv "customers.csv"
# * show first 5 rows
# * ![image.png](attachment:image.png)

# %%
import pandas as pd

df = pd.read_csv(r"./customers.csv")
df.head()
# Out:
#   customer_id   age  gender      region   income married  children  car  \
# 0     ID12101  48.0       F         NaN  17546.0      NO       1.0   NO
# 1     ID12102  40.0    MALE        TOWN  30085.1     YES       3.0  YES
# 2     ID12103  51.0  FEMALE  INNER_CITY  16575.4     YES       0.0  YES
# 3     ID12104  23.0  FEMALE        TOWN  20375.4     YES       3.0   NO
# 4     ID12105   NaN    MALE       RURAL  50576.3     YES       0.0   NO
#
#   response
# 0       NO
# 1       NO
# 2      YES
# 3       NO
# 4      YES

# %% [markdown]
# # Step1: Understand dataset

# %%
# df.shape
df.shape
# Out:
# (600, 9)

# %%
# read the first 7 rows

df.head(7)
# Out:
#   customer_id   age  gender      region    income married  children  car  \
# 0     ID12101  48.0       F         NaN  17546.00      NO       1.0   NO
# 1     ID12102  40.0    MALE        TOWN  30085.10     YES       3.0  YES
# 2     ID12103  51.0  FEMALE  INNER_CITY  16575.40     YES       0.0  YES
# 3     ID12104  23.0  FEMALE        TOWN  20375.40     YES       3.0   NO
# 4     ID12105   NaN    MALE       RURAL  50576.30     YES       0.0   NO
# 5     ID12106  57.0   WOMAN        TOWN  37869.60     YES       2.0   NO
# 6     ID12107  22.0    MALE       RURAL   8877.07      NO       0.0   NO
#
#   response
# 0       NO
# 1       NO
# 2      YES
# 3       NO
# 4      YES
# 5      YES
# 6       NO

# %%
df.tail(7)
# Out:
#     customer_id   age  gender      region    income married  children  car  \
# 593     ID12694  65.0    MALE    SUBURBAN  51417.00     YES       2.0   NO
# 594     ID12695  59.0  FEMALE       RURAL  30971.80     YES       3.0  YES
# 595     ID12696  61.0  FEMALE  INNER_CITY  47025.00      NO       2.0  YES
# 596     ID12697  30.0  FEMALE  INNER_CITY   9672.25     YES       0.0  YES
# 597     ID12698  31.0  FEMALE        TOWN  15976.30     YES       0.0  YES
# 598     ID12699  29.0    MALE  INNER_CITY  14711.80     YES       0.0   NO
# 599     ID12700  38.0    MALE        TOWN  26671.60      NO       0.0  YES
#
#     response
# 593      YES
# 594      YES
# 595      YES
# 596      YES
# 597      YES
# 598      YES
# 599       NO

# %% [markdown]
# - return an arry of column names
# ![image.png](attachment:image.png)

# %%
# return an arry of column names

df.columns.to_numpy()
# Out:
# array(['customer_id', 'age', 'gender', 'region', 'income', 'married',
#        'children', 'car', 'response'], dtype=object)

# %% [markdown]
# - return a list of column names
# ![image.png](attachment:image.png)

# %%
# return a list of column names

list(df.columns)
# Out:
# ['customer_id',
#  'age',
#  'gender',
#  'region',
#  'income',
#  'married',
#  'children',
#  'car',
#  'response']

# %% [markdown]
# # Step2: Check missing value
# * df.isnull() # checking missing values
# * df.isnull().sum() # check missing by variable
# * df.isnull().sum().sum() # check how many missing values in data
# * df.nunique() function represents the unique values present in each column of the dataframe
# * df.-columnName.unique() function represents the unique values present in each column of the dataframe

# %%
# checking missing values, then show first 5 rows

# Check missing values in each column
df.isnull().sum()

# Show first 5 rows
df.head()
# Out:
#   customer_id   age  gender      region   income married  children  car  \
# 0     ID12101  48.0       F         NaN  17546.0      NO       1.0   NO
# 1     ID12102  40.0    MALE        TOWN  30085.1     YES       3.0  YES
# 2     ID12103  51.0  FEMALE  INNER_CITY  16575.4     YES       0.0  YES
# 3     ID12104  23.0  FEMALE        TOWN  20375.4     YES       3.0   NO
# 4     ID12105   NaN    MALE       RURAL  50576.3     YES       0.0   NO
#
#   response
# 0       NO
# 1       NO
# 2      YES
# 3       NO
# 4      YES

# %%
df.isnull().sum()
# Out:
# customer_id    0
# age            8
# gender         0
# region         6
# income         0
# married        0
# children       5
# car            0
# response       0
# dtype: int64

# %%
# check how many missing values in data

df.isnull().sum().sum()
# Out:
# np.int64(19)

# %%
df.nunique()
# Out:
# customer_id    598
# age             56
# gender           6
# region           4
# income         599
# married          2
# children         4
# car              2
# response         2
# dtype: int64

# %%
# check  unique values present in "gender" column of the dataframe
df['gender'].unique()
# Out:
# array(['F', 'MALE', 'FEMALE', 'WOMAN', 'MAN', 'M'], dtype=object)

# %% [markdown]
# # Step 3: Remove the NaN values using dropna() method
# * dataframe.dropna(axis, how, thresh, subset, inplace)

# %%
## check isnull() each column

df.isnull().sum()
# Out:
# customer_id    0
# age            8
# gender         0
# region         6
# income         0
# married        0
# children       5
# car            0
# response       0
# dtype: int64

# %% [markdown]
# ### Remove NaN in datafram , ONLY Column"age" and "region", then assign to dfCustomer

# %%
# Remove NaN in datafram value on "age" and "region" column ... 
df.dropna(subset=['age', 'region'], inplace=True)

df.dropna(subset=['age', 'region'], inplace=True)

# %%
# Check NaN value 
df.isnull().sum()
# Out:
# customer_id    0
# age            0
# gender         0
# region         0
# income         0
# married        0
# children       5
# car            0
# response       0
# dtype: int64

# %% [markdown]
# ### Drop NaN every rows (axis=0) from df, then assign the new value to dataframe of dfCustomer

# %%
# Drop NaN every rows (axis=0) from df, then assign the new value to dataframe of dfCustomer
# Drop NaN from every row (axis=0) and assign to new DataFrame
dfCustomer = df.dropna(axis=0)

# %%
dfCustomer.head()
# Out:
#   customer_id   age  gender      region    income married  children  car  \
# 1     ID12102  40.0    MALE        TOWN  30085.10     YES       3.0  YES
# 2     ID12103  51.0  FEMALE  INNER_CITY  16575.40     YES       0.0  YES
# 3     ID12104  23.0  FEMALE        TOWN  20375.40     YES       3.0   NO
# 5     ID12106  57.0   WOMAN        TOWN  37869.60     YES       2.0   NO
# 6     ID12107  22.0    MALE       RURAL   8877.07      NO       0.0   NO
#
#   response
# 1       NO
# 2      YES
# 3       NO
# 5      YES
# 6       NO

# %%
# Check NaN value 

dfCustomer.isnull().sum()
# Out:
# customer_id    0
# age            0
# gender         0
# region         0
# income         0
# married        0
# children       0
# car            0
# response       0
# dtype: int64

# %% [markdown]
# # Step 4: Fill in NaN missing values
# ## Loading csv file customers again in "df" Data frame again
# * DataFrame.fillna(value, axis, inplace)
# * DataFrame.Column_Name.fillna(value, axis, inplace)
# ![image.png](attachment:image.png)

# %%
# Load dataset again for practice fill value in Null values

df = pd.read_csv(r"./customers.csv")

# Check NaN value 

df.isnull().sum()
# Out:
# customer_id    0
# age            8
# gender         0
# region         6
# income         0
# married        0
# children       5
# car            0
# response       0
# dtype: int64

# %%
df.head(5)
# Out:
#   customer_id   age  gender      region   income married  children  car  \
# 0     ID12101  48.0       F         NaN  17546.0      NO       1.0   NO
# 1     ID12102  40.0    MALE        TOWN  30085.1     YES       3.0  YES
# 2     ID12103  51.0  FEMALE  INNER_CITY  16575.4     YES       0.0  YES
# 3     ID12104  23.0  FEMALE        TOWN  20375.4     YES       3.0   NO
# 4     ID12105   NaN    MALE       RURAL  50576.3     YES       0.0   NO
#
#   response
# 0       NO
# 1       NO
# 2      YES
# 3       NO
# 4      YES

# %% [markdown]
# * **fill in missing value with  50  and save the data to column age**
# * **datafram.column_name.fillna(50,inplace=True)**
# * ![image.png](attachment:image.png)

# %%
# fill in missing with singular column

df['age'].fillna(50, inplace=True)
# Out:
# C:\Users\Aye MIn Aung\AppData\Local\Temp\ipykernel_14840\1727737094.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(50, inplace=True)

# %%
# Check NaN value 
df.isnull().sum()
# Out:
# customer_id    0
# age            0
# gender         0
# region         6
# income         0
# married        0
# children       5
# car            0
# response       0
# dtype: int64

# %% [markdown]
# * **fill in missing with a string : "TOWN" and save the data to column region**
# * **datafram.column_name.fillna('TOWN',inplace=True)**
# !![image-2.png](attachment:image-2.png)

# %%
# fill in missing with a string : "TOWN" and save the data to column region
df['region'].fillna('TOWN', inplace=True)
# Out:
# C:\Users\Aye MIn Aung\AppData\Local\Temp\ipykernel_14840\265802060.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['region'].fillna('TOWN', inplace=True)

# %%
# Check NaN value 

df.isnull().sum()
# Out:
# customer_id    0
# age            0
# gender         0
# region         0
# income         0
# married        0
# children       5
# car            0
# response       0
# dtype: int64

# %% [markdown]
# * **fill in missing with values with sample median() in column "children"**
# * **datafram.column_name.fillna(df.children.median(),inplace=True)**

# %%
# fill in missing with values with sample median() in column "children"

df['children'].fillna(df['children'].median(), inplace=True)
# Out:
# C:\Users\Aye MIn Aung\AppData\Local\Temp\ipykernel_14840\1003567347.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['children'].fillna(df['children'].median(), inplace=True)

# %%
# Check NaN value 

df.isnull().sum()
# Out:
# customer_id    0
# age            0
# gender         0
# region         0
# income         0
# married        0
# children       0
# car            0
# response       0
# dtype: int64

# %% [markdown]
# ### Step 5.1 Check Duplicate Value in Column "customer_id"
# * **DataFrame.Column_Name.duplicated().sum()**
# ![image.png](attachment:image.png)

# %%
#Handle Duplicate Value in "customer_id" Column

df['customer_id'].duplicated().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ### Step 5.2: Remove Duplicate Value in Column "customer_id"
# * **DataFrame.drop_duplicates(subset =' ', inplace = True)**
# ![image.png](attachment:image.png)

# %%
#Remove Duplicate Value in Column
df.drop_duplicates(subset='customer_id', inplace=True)

# %%
#Check duplicate rows

df['customer_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Exploration Data Analysis Technique

# %% [markdown]
# ## Count Plot :: Seaborn
# * **sns.countplot(x=df[column_name])**
# * **using column name is "gender"**
# ![image.png](attachment:image.png)

# %%
df_raw = pd.read_csv(r"./customers.csv")

sns.countplot(x=df_raw['gender'])
plt.xlabel('gender')
plt.ylabel('count')
plt.title('Count Plot of Gender (Before Cleaning)')
plt.show()

# %% [markdown]
# ## Replace value
# * **DataFrame.replace(value, inplace = True)**
# * **Create Function replaceValueGender() to replace follow value as below**
# ** replace F AND WOMEN to FEMALE
# ** replace M AND MAN to MALE

# %%
# Create function replaceValueGender():
def replaceValueGender(df):
    df.replace(
        {
            'gender': {
                'F': 'FEMALE',
                'WOMAN': 'FEMALE',
                'M': 'MALE',
                'MAN': 'MALE'
            }
        },
        inplace=True
    )

# %%
# Calling function replaceValueGender()
replaceValueGender(df)
df.head(5)
# Out:
#   customer_id   age  gender      region   income married  children  car  \
# 0     ID12101  48.0  FEMALE        TOWN  17546.0      NO       1.0   NO
# 1     ID12102  40.0    MALE        TOWN  30085.1     YES       3.0  YES
# 2     ID12103  51.0  FEMALE  INNER_CITY  16575.4     YES       0.0  YES
# 3     ID12104  23.0  FEMALE        TOWN  20375.4     YES       3.0   NO
# 4     ID12105  50.0    MALE       RURAL  50576.3     YES       0.0   NO
#
#   response
# 0       NO
# 1       NO
# 2      YES
# 3       NO
# 4      YES

# %% [markdown]
# ### Count Plot :: Seaborn
# #### using sns.countplot(x=df[column_name])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

column_name = 'gender'

sns.countplot(x=df[column_name])
plt.xlabel('gender')
plt.ylabel('count')
plt.title('Count Plot of Gender')
plt.show()

# %% [markdown]
# ### Box Plot :: Matplotlib
# * **data_frame.boxplot(column ='column_name')**
# * **using column name is "age"**

# %%
## Create boxplot graph

import matplotlib.pyplot as plt

# Create boxplot for age column
df.boxplot(column='age')

# Labels & title
plt.xlabel('Age')
plt.ylabel('Value')
plt.title('Box Plot of Age')

# Show plot
plt.show()

# %% [markdown]
# ### Drop value
# * **DataFrame.drop(index, inplace = True)**
# ** Index is df.index[df['age'] >= 80]

# %%
df.index[df['age'] >= 80]

# %%
# Drop value in finding index :  df.index[df['age'] >= 80]


# Find index where age >= 80
df.drop(df.index[df['age'] >= 80], inplace=True)
df.head()
# Out:
#   customer_id   age  gender      region   income married  children  car  \
# 0     ID12101  48.0  FEMALE        TOWN  17546.0      NO       1.0   NO
# 1     ID12102  40.0    MALE        TOWN  30085.1     YES       3.0  YES
# 2     ID12103  51.0  FEMALE  INNER_CITY  16575.4     YES       0.0  YES
# 3     ID12104  23.0  FEMALE        TOWN  20375.4     YES       3.0   NO
# 4     ID12105  50.0    MALE       RURAL  50576.3     YES       0.0   NO
#
#   response
# 0       NO
# 1       NO
# 2      YES
# 3       NO
# 4      YES

# %%
# Create boxplot graph of colunm age again

import matplotlib.pyplot as plt

# Create boxplot graph of column age again
df.boxplot(column='age')

plt.title('Box Plot of Age')
plt.ylabel('age')
plt.show()
